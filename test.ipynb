# %%
from dataGenerator import toyData
from neuralGenerator import createMultipleNeuralNetworks
from utils import utils

# %%
X, y = toyData(1, plot=True).main()

# %%
createMultipleNeuralNetworks(X, y).main()
# Out:
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_275"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_550 (Dense)           (None, None, 500, 512)    1536
#
#  dense_551 (Dense)           (None, None, 500, 2)      1026
#
# ...
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_550_input'), name='dense_550_input', description="created by layer 'dense_550_input'"), but it was called on an input with incompatible shape (None, 2).
# ...

# %%
NN_inputs = utils().get_inputs_from_json()
datasets = createMultipleNeuralNetworks(X, y, *NN_inputs).main()
# Out:
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_332"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_664 (Dense)           (None, None, 500, 512)    1536
#
#  dense_665 (Dense)           (None, None, 500, 2)      1026
#
# ...
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_664_input'), name='dense_664_input', description="created by layer 'dense_664_input'"), but it was called on an input with incompatible shape (None, 2).
# ...

# %%
datasets
