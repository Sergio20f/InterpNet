# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle, islice

# %%
class toyData():
    def __init__(self, dataset_n=None, random_seed_n=0, n_samples=500, plot=False):
        self.dataset_n = dataset_n
        self.random_seed_n = random_seed_n
        self.n_samples = n_samples
        self.plot = plot
        
    def generate_data(self):
        from sklearn import cluster, datasets, mixture
        np.random.seed(self.random_seed_n)

        # ============
        # Generate datasets. We choose the size big enough to see the scalability
        # of the algorithms, but not too big to avoid too long running times
        # ============
        n_samples = self.n_samples
        noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
        noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
        blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
        no_structure = np.random.rand(n_samples, 2), None

        # Anisotropicly distributed data
        random_state = 170
        X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
        transformation = [[0.6, -0.6], [-0.4, 0.8]]
        X_aniso = np.dot(X, transformation)
        aniso = (X_aniso, y)

        # blobs with varied variances
        varied = datasets.make_blobs(
            n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
        )

        # ============
        # Set up cluster parameters
        # ============
        if self.plot:
            plt.figure(figsize=(9 * 2 + 3, 13))
            plt.subplots_adjust(left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.05, hspace=0.01)

        plot_num = 1

        default_base = {
            "quantile": 0.3,
            "eps": 0.3,
            "damping": 0.9,
            "preference": -200,
            "n_neighbors": 3,
            "n_clusters": 3,
            "min_samples": 7,
            "xi": 0.05,
            "min_cluster_size": 0.1,
        }

        datasets = [
            (
                noisy_circles,
                {
                    "damping": 0.77,
                    "preference": -240,
                    "quantile": 0.2,
                    "n_clusters": 2,
                    "min_samples": 7,
                    "xi": 0.08,
                },
            ),
            (
                noisy_moons,
                {
                    "damping": 0.75,
                    "preference": -220,
                    "n_clusters": 2,
                    "min_samples": 7,
                    "xi": 0.1,
                },
            ),
            (
                varied,
                {
                    "eps": 0.18,
                    "n_neighbors": 2,
                    "min_samples": 7,
                    "xi": 0.01,
                    "min_cluster_size": 0.2,
                },
            ),
            (
                aniso,
                {
                    "eps": 0.15,
                    "n_neighbors": 2,
                    "min_samples": 7,
                    "xi": 0.1,
                    "min_cluster_size": 0.2,
                },
            ),
            (blobs, {"min_samples": 7, "xi": 0.1, "min_cluster_size": 0.2}),
            (no_structure, {}),
        ]
        datasets = [i[0] for i in datasets]
        return datasets
    
    def get_colors(self, y):
        colors = np.array(
                list(
                    islice(
                        cycle(
                            [
                                "#377eb8",
                                "#ff7f00",
                                "#4daf4a",
                                "#f781bf",
                                "#a65628",
                                "#984ea3",
                                "#999999",
                                "#e41a1c",
                                "#dede00",
                            ]
                        ),
                        int(max(y) + 1),
                    )
                )
        )

        return colors
    
    def plot_data(self, X, y):
        colors = self.get_colors(y)
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y])
        plt.xticks(())
        plt.yticks(())
        plt.show()
        
    def one_hot_encoding(self, array_y):
        y_one_hot_encoded = np.zeros((array_y.size, array_y.max() + 1))
        y_one_hot_encoded[np.arange(array_y.size), array_y] = 1
        return y_one_hot_encoded
    
    def main(self):
        # Returns all datasets
        datasets = self.generate_data()
        if self.dataset_n == None:
            X = [x[0] for x in datasets]
            y = [y[1] for y in datasets]
            y = self.one_hot_encoding(y)
            return (X, y)

        dataset = datasets[self.dataset_n]
        X, y = dataset[0], dataset[1]
        
        if self.plot == True:
            self.plot_data(X, y)
        
        y = self.one_hot_encoding(y)
        return (X, y)

# %%
(X, y) = toyData(1, n_samples=1000, plot=True).main()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
class createMultipleNeuralNetworks():
    
    def __init__(self, train_X, train_y, n_neural_networks=10,n_hidden_layers=0, n_categories=2, neuron_number_list = [512], activation_function_list=['relu', 'softmax'], loss_list=['binary_crossentropy'], optimizer_list=['adam'], epochs_list=[1], batch_size_list=[32], input_shape=(None, 500, 2)):
        self.train_X = train_X
        self.train_y = train_y
        self.n_neural_networks = int(n_neural_networks)
        self.n_hidden_layers = int(n_hidden_layers)
        self.n_categories = int(n_categories)
        self.neuron_number_list = neuron_number_list
        self.activation_function_list = list(activation_function_list)
        self.loss_list = list(loss_list)
        self.optimizer_list = list(optimizer_list)
        self.epochs_list = list(epochs_list)
        self.batch_size_list = list(batch_size_list)
        self.input_shape = input_shape
    
    def add_dense_layer(self, model, input_layer=False):
        # Random number of layers, and activation function
        neuron_number = np.random.choice(self.neuron_number_list)
        print("Number of nuerons: ", neuron_number)
        activation_function = np.random.choice(self.activation_function_list)
        print("Activation Function: ", activation_function)
        
        if input_layer is True:
            model.add(Dense(neuron_number, activation=activation_function, input_shape= self.input_shape))   
        else:
            model.add(Dense(neuron_number, activation=activation_function))   
        
        return model
    
    def getConfigFiles(self, path = '\\Config\\ETL\\', config_name = ''):
        current_path = os.getcwd()
        folder_code = os.path.dirname(current_path)
        folder_working =  os.path.dirname(folder_code)
        config_path = folder_working + path + config_name
        return config_path
    
    def generate_model(self):
        model = Sequential()
        
        # Input layer
        model = self.add_dense_layer(model, input_layer=True)
        
        # Hidden layers
        for _ in range(self.n_hidden_layers):
            model = self.add_dense_layer(model,  input_layer=False)

        # Output layer
        model.add(Dense(self.n_categories, activation="softmax"))
        print('Random neural network architecture summary: ')
        model.summary()
        
        return model 
    
    def save_models(self, model):
        return model
    
    def train(self, model):
        loss = np.random.choice(self.loss_list)
        optimizer = np.random.choice(self.optimizer_list)
        model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])
        
        batch_size = np.random.choice(self.batch_size_list)
        epochs = np.random.choice(self.epochs_list)
        # Fitting model on training data
        model.fit(self.train_X, self.train_y, batch_size=batch_size, epochs=epochs, verbose=1)
        return model
    
    def main(self):
        for _ in range(1, self.n_neural_networks):
            model = self.generate_model()
            model = self.train(model)
            # self.save_models()
            
            
        neural_networks_list = [self.generate_model() for _ in range(self.n_neural_networks)]
        return neural_networks_list

# %%
models = createMultipleNeuralNetworks(X, y, n_neural_networks=10).main()
# Out:
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_91"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_168 (Dense)           (None, None, 500, 512)    1536
#
#  dense_169 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_168_input'), name='dense_168_input', description="created by layer 'dense_168_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_168_input'), name='dense_168_input', description="created by layer 'dense_168_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5742 - accuracy: 0.8200
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_92"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_170 (Dense)           (None, None, 500, 512)    1536
#
#  dense_171 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_170_input'), name='dense_170_input', description="created by layer 'dense_170_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_170_input'), name='dense_170_input', description="created by layer 'dense_170_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5882 - accuracy: 0.7710
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_93"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_172 (Dense)           (None, None, 500, 512)    1536
#
#  dense_173 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_172_input'), name='dense_172_input', description="created by layer 'dense_172_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_172_input'), name='dense_172_input', description="created by layer 'dense_172_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5040
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_94"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_174 (Dense)           (None, None, 500, 512)    1536
#
#  dense_175 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_174_input'), name='dense_174_input', description="created by layer 'dense_174_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_174_input'), name='dense_174_input', description="created by layer 'dense_174_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5664 - accuracy: 0.8070
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_95"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_176 (Dense)           (None, None, 500, 512)    1536
#
#  dense_177 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_176_input'), name='dense_176_input', description="created by layer 'dense_176_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_176_input'), name='dense_176_input', description="created by layer 'dense_176_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.4980
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_96"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_178 (Dense)           (None, None, 500, 512)    1536
#
#  dense_179 (Dense)           (None, None, 500, 2)      1026
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_178_input'), name='dense_178_input', description="created by layer 'dense_178_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_178_input'), name='dense_178_input', description="created by layer 'dense_178_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5505 - accuracy: 0.8250
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_97"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_180 (Dense)           (None, None, 500, 512)    1536
#
#  dense_181 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_180_input'), name='dense_180_input', description="created by layer 'dense_180_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_180_input'), name='dense_180_input', description="created by layer 'dense_180_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5673 - accuracy: 0.7750
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_98"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_182 (Dense)           (None, None, 500, 512)    1536
#
#  dense_183 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_182_input'), name='dense_182_input', description="created by layer 'dense_182_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_182_input'), name='dense_182_input', description="created by layer 'dense_182_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5758 - accuracy: 0.8000
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_99"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_184 (Dense)           (None, None, 500, 512)    1536
#
#  dense_185 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_184_input'), name='dense_184_input', description="created by layer 'dense_184_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_184_input'), name='dense_184_input', description="created by layer 'dense_184_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5671 - accuracy: 0.7900
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_100"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_186 (Dense)           (None, None, 500, 512)    1536
#
#  dense_187 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_101"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_188 (Dense)           (None, None, 500, 512)    1536
#
#  dense_189 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_102"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_190 (Dense)           (None, None, 500, 512)    1536
#
#  dense_191 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_103"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_192 (Dense)           (None, None, 500, 512)    1536
#
#  dense_193 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_104"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_194 (Dense)           (None, None, 500, 512)    1536
#
#  dense_195 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_105"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_196 (Dense)           (None, None, 500, 512)    1536
#
#  dense_197 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_106"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_198 (Dense)           (None, None, 500, 512)    1536
#
#  dense_199 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_107"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_200 (Dense)           (None, None, 500, 512)    1536
#
#  dense_201 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_108"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_202 (Dense)           (None, None, 500, 512)    1536
#
#  dense_203 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_109"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_204 (Dense)           (None, None, 500, 512)    1536
#
#  dense_205 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
import json
def get_inputs_from_json(path = '\\configs\\', config_name = 'neural_network.cfg'):
    current_path = os.getcwd()
    config_path = current_path + "\\configs\\" + "configurations.json"
    with open(config_path) as f:
            file = json.load(f)
            return list(file['Neural_Network_Generator'].values())

# %%
# Run from json file
nn_inputs = get_inputs_from_json()
createMultipleNeuralNetworks(X, y, *nn_inputs).main()
# Out:
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_110"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_206 (Dense)           (None, None, 500, 512)    1536
#
#  dense_207 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_206_input'), name='dense_206_input', description="created by layer 'dense_206_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_206_input'), name='dense_206_input', description="created by layer 'dense_206_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5729 - accuracy: 0.7790
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_111"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_208 (Dense)           (None, None, 500, 512)    1536
#
#  dense_209 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_208_input'), name='dense_208_input', description="created by layer 'dense_208_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_208_input'), name='dense_208_input', description="created by layer 'dense_208_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5658 - accuracy: 0.8280
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_112"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_210 (Dense)           (None, None, 500, 512)    1536
#
#  dense_211 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_210_input'), name='dense_210_input', description="created by layer 'dense_210_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_210_input'), name='dense_210_input', description="created by layer 'dense_210_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5730
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_113"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_212 (Dense)           (None, None, 500, 512)    1536
#
#  dense_213 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_212_input'), name='dense_212_input', description="created by layer 'dense_212_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_212_input'), name='dense_212_input', description="created by layer 'dense_212_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 1s 1ms/step - loss: 0.6930 - accuracy: 0.5000
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_114"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_214 (Dense)           (None, None, 500, 512)    1536
#
#  dense_215 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_214_input'), name='dense_214_input', description="created by layer 'dense_214_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_214_input'), name='dense_214_input', description="created by layer 'dense_214_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.7980
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_115"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_216 (Dense)           (None, None, 500, 512)    1536
#
#  dense_217 (Dense)           (None, None, 500, 2)      1026
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_216_input'), name='dense_216_input', description="created by layer 'dense_216_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_216_input'), name='dense_216_input', description="created by layer 'dense_216_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.4930
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_116"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_218 (Dense)           (None, None, 500, 512)    1536
#
#  dense_219 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_218_input'), name='dense_218_input', description="created by layer 'dense_218_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_218_input'), name='dense_218_input', description="created by layer 'dense_218_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5609 - accuracy: 0.7950
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_117"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_220 (Dense)           (None, None, 500, 512)    1536
#
#  dense_221 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_220_input'), name='dense_220_input', description="created by layer 'dense_220_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_220_input'), name='dense_220_input', description="created by layer 'dense_220_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5699 - accuracy: 0.7740
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_118"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_222 (Dense)           (None, None, 500, 512)    1536
#
#  dense_223 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_222_input'), name='dense_222_input', description="created by layer 'dense_222_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_222_input'), name='dense_222_input', description="created by layer 'dense_222_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5605 - accuracy: 0.7870
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_119"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_224 (Dense)           (None, None, 500, 512)    1536
#
#  dense_225 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_224_input'), name='dense_224_input', description="created by layer 'dense_224_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_224_input'), name='dense_224_input', description="created by layer 'dense_224_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.4860
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_120"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_226 (Dense)           (None, None, 500, 512)    1536
#
#  dense_227 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_226_input'), name='dense_226_input', description="created by layer 'dense_226_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_226_input'), name='dense_226_input', description="created by layer 'dense_226_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.5670
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_121"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_228 (Dense)           (None, None, 500, 512)    1536
#
#  dense_229 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_228_input'), name='dense_228_input', description="created by layer 'dense_228_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_228_input'), name='dense_228_input', description="created by layer 'dense_228_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.5000
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_122"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_230 (Dense)           (None, None, 500, 512)    1536
#
#  dense_231 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_230_input'), name='dense_230_input', description="created by layer 'dense_230_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_230_input'), name='dense_230_input', description="created by layer 'dense_230_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7870
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_123"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_232 (Dense)           (None, None, 500, 512)    1536
#
#  dense_233 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_232_input'), name='dense_232_input', description="created by layer 'dense_232_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_232_input'), name='dense_232_input', description="created by layer 'dense_232_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.4860
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_124"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_234 (Dense)           (None, None, 500, 512)    1536
#
#  dense_235 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_234_input'), name='dense_234_input', description="created by layer 'dense_234_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_234_input'), name='dense_234_input', description="created by layer 'dense_234_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5582 - accuracy: 0.8110
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_125"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_236 (Dense)           (None, None, 500, 512)    1536
#
#  dense_237 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_236_input'), name='dense_236_input', description="created by layer 'dense_236_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_236_input'), name='dense_236_input', description="created by layer 'dense_236_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5705 - accuracy: 0.7950
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_126"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_238 (Dense)           (None, None, 500, 512)    1536
#
#  dense_239 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_238_input'), name='dense_238_input', description="created by layer 'dense_238_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_238_input'), name='dense_238_input', description="created by layer 'dense_238_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5744 - accuracy: 0.7970
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_127"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_240 (Dense)           (None, None, 500, 512)    1536
#
#  dense_241 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_240_input'), name='dense_240_input', description="created by layer 'dense_240_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_240_input'), name='dense_240_input', description="created by layer 'dense_240_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.7820
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_242 (Dense)           (None, None, 500, 512)    1536
#
#  dense_243 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_242_input'), name='dense_242_input', description="created by layer 'dense_242_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_242_input'), name='dense_242_input', description="created by layer 'dense_242_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7910
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_129"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_244 (Dense)           (None, None, 500, 512)    1536
#
#  dense_245 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_244_input'), name='dense_244_input', description="created by layer 'dense_244_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_244_input'), name='dense_244_input', description="created by layer 'dense_244_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5000
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_130"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_246 (Dense)           (None, None, 500, 512)    1536
#
#  dense_247 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_246_input'), name='dense_246_input', description="created by layer 'dense_246_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_246_input'), name='dense_246_input', description="created by layer 'dense_246_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.5340
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_131"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_248 (Dense)           (None, None, 500, 512)    1536
#
#  dense_249 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_248_input'), name='dense_248_input', description="created by layer 'dense_248_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_248_input'), name='dense_248_input', description="created by layer 'dense_248_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5795 - accuracy: 0.7730
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_132"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_250 (Dense)           (None, None, 500, 512)    1536
#
#  dense_251 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_250_input'), name='dense_250_input', description="created by layer 'dense_250_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_250_input'), name='dense_250_input', description="created by layer 'dense_250_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5615 - accuracy: 0.8230
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_133"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_252 (Dense)           (None, None, 500, 512)    1536
#
#  dense_253 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_252_input'), name='dense_252_input', description="created by layer 'dense_252_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_252_input'), name='dense_252_input', description="created by layer 'dense_252_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7760
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_134"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_254 (Dense)           (None, None, 500, 512)    1536
#
#  dense_255 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_254_input'), name='dense_254_input', description="created by layer 'dense_254_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_254_input'), name='dense_254_input', description="created by layer 'dense_254_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 1s 1ms/step - loss: 0.6930 - accuracy: 0.5000
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_135"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_256 (Dense)           (None, None, 500, 512)    1536
#
#  dense_257 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_256_input'), name='dense_256_input', description="created by layer 'dense_256_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_256_input'), name='dense_256_input', description="created by layer 'dense_256_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.5240
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_136"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_258 (Dense)           (None, None, 500, 512)    1536
#
#  dense_259 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_258_input'), name='dense_258_input', description="created by layer 'dense_258_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_258_input'), name='dense_258_input', description="created by layer 'dense_258_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5670 - accuracy: 0.8100
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_137"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_260 (Dense)           (None, None, 500, 512)    1536
#
#  dense_261 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_260_input'), name='dense_260_input', description="created by layer 'dense_260_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_260_input'), name='dense_260_input', description="created by layer 'dense_260_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.7570
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_138"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_262 (Dense)           (None, None, 500, 512)    1536
#
#  dense_263 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_262_input'), name='dense_262_input', description="created by layer 'dense_262_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_262_input'), name='dense_262_input', description="created by layer 'dense_262_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5639 - accuracy: 0.7610
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_264 (Dense)           (None, None, 500, 512)    1536
#
#  dense_265 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_264_input'), name='dense_264_input', description="created by layer 'dense_264_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_264_input'), name='dense_264_input', description="created by layer 'dense_264_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5702 - accuracy: 0.8010
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_266 (Dense)           (None, None, 500, 512)    1536
#
#  dense_267 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_266_input'), name='dense_266_input', description="created by layer 'dense_266_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, None, 500, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 500, 2), dtype=tf.float32, name='dense_266_input'), name='dense_266_input', description="created by layer 'dense_266_input'"), but it was called on an input with incompatible shape (None, 2).
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5000
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_141"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_268 (Dense)           (None, None, 500, 512)    1536
#
#  dense_269 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# ...
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_296"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_578 (Dense)           (None, None, 500, 512)    1536
#
#  dense_579 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_297"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_580 (Dense)           (None, None, 500, 512)    1536
#
#  dense_581 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_298"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_582 (Dense)           (None, None, 500, 512)    1536
#
#  dense_583 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_299"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_584 (Dense)           (None, None, 500, 512)    1536
#
#  dense_585 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_300"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_586 (Dense)           (None, None, 500, 512)    1536
#
#  dense_587 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_301"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_588 (Dense)           (None, None, 500, 512)    1536
#
#  dense_589 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_302"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_590 (Dense)           (None, None, 500, 512)    1536
#
#  dense_591 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_303"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_592 (Dense)           (None, None, 500, 512)    1536
#
#  dense_593 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_304"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_594 (Dense)           (None, None, 500, 512)    1536
#
#  dense_595 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_305"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_596 (Dense)           (None, None, 500, 512)    1536
#
#  dense_597 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_306"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_598 (Dense)           (None, None, 500, 512)    1536
#
#  dense_599 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  relu
# Random neural network architecture summary:
# Model: "sequential_307"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_600 (Dense)           (None, None, 500, 512)    1536
#
#  dense_601 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# Number of nuerons:  512
# Activation Function:  softmax
# Random neural network architecture summary:
# Model: "sequential_308"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_602 (Dense)           (None, None, 500, 512)    1536
#
#  dense_603 (Dense)           (None, None, 500, 2)      1026
#
# =================================================================
# Total params: 2,562
# Trainable params: 2,562
# Non-trainable params: 0
# _________________________________________________________________
# [<keras.engine.sequential.Sequential at 0x231a4691040>,
#  <keras.engine.sequential.Sequential at 0x231a6d3fa90>,
#  <keras.engine.sequential.Sequential at 0x231a47fd100>,
#  <keras.engine.sequential.Sequential at 0x231a6d17d60>,
#  <keras.engine.sequential.Sequential at 0x231a45e1fd0>,
#  <keras.engine.sequential.Sequential at 0x231a45e1be0>,
#  <keras.engine.sequential.Sequential at 0x2319c629e50>,
#  <keras.engine.sequential.Sequential at 0x231a47fdc10>,
#  <keras.engine.sequential.Sequential at 0x231a42ce8e0>,
#  <keras.engine.sequential.Sequential at 0x231a46497f0>,
#  <keras.engine.sequential.Sequential at 0x2319c5bcee0>,
#  <keras.engine.sequential.Sequential at 0x2319c610eb0>,
#  <keras.engine.sequential.Sequential at 0x2319c535070>,
#  <keras.engine.sequential.Sequential at 0x231a4960370>,
#  <keras.engine.sequential.Sequential at 0x231a480bbe0>,
#  <keras.engine.sequential.Sequential at 0x231a49377c0>,
#  <keras.engine.sequential.Sequential at 0x2319c6e6190>,
#  <keras.engine.sequential.Sequential at 0x2319c6e6cd0>,
#  <keras.engine.sequential.Sequential at 0x231a4345f10>,
#  <keras.engine.sequential.Sequential at 0x231a4345e50>,
#  <keras.engine.sequential.Sequential at 0x231a5a42430>,
#  <keras.engine.sequential.Sequential at 0x2319c6cdf70>,
#  <keras.engine.sequential.Sequential at 0x231a3f5dbb0>,
#  <keras.engine.sequential.Sequential at 0x2319c66cd90>,
#  <keras.engine.sequential.Sequential at 0x231a26deca0>,
#  <keras.engine.sequential.Sequential at 0x231a480b850>,
#  <keras.engine.sequential.Sequential at 0x2319c5bcd00>,
#  <keras.engine.sequential.Sequential at 0x2319c6cd970>,
#  <keras.engine.sequential.Sequential at 0x231a3fb75b0>,
#  <keras.engine.sequential.Sequential at 0x231a45175e0>,
#  <keras.engine.sequential.Sequential at 0x231a3f5dc10>,
#  <keras.engine.sequential.Sequential at 0x231a4960580>,
#  <keras.engine.sequential.Sequential at 0x2319c5bc040>,
#  <keras.engine.sequential.Sequential at 0x231a43ee2e0>,
#  <keras.engine.sequential.Sequential at 0x2319c535610>,
#  <keras.engine.sequential.Sequential at 0x231a4660af0>,
#  <keras.engine.sequential.Sequential at 0x231a41ba760>,
#  <keras.engine.sequential.Sequential at 0x231a4638dc0>,
#  <keras.engine.sequential.Sequential at 0x231a2722f40>,
#  <keras.engine.sequential.Sequential at 0x231a496f580>,
#  <keras.engine.sequential.Sequential at 0x231a4660cd0>,
#  <keras.engine.sequential.Sequential at 0x231a460a2e0>,
#  <keras.engine.sequential.Sequential at 0x231a43fc0a0>,
#  <keras.engine.sequential.Sequential at 0x231a438c460>,
#  <keras.engine.sequential.Sequential at 0x231a43fcdc0>,
#  <keras.engine.sequential.Sequential at 0x231a468dee0>,
#  <keras.engine.sequential.Sequential at 0x231a4949700>,
#  <keras.engine.sequential.Sequential at 0x231a4663220>,
#  <keras.engine.sequential.Sequential at 0x231a44255b0>,
#  <keras.engine.sequential.Sequential at 0x231a460a9a0>,
#  <keras.engine.sequential.Sequential at 0x231a3f5d4c0>,
#  <keras.engine.sequential.Sequential at 0x231a496f070>,
#  <keras.engine.sequential.Sequential at 0x231a46630d0>,
#  <keras.engine.sequential.Sequential at 0x231a43bcfa0>,
#  <keras.engine.sequential.Sequential at 0x231a3e7c3d0>,
#  <keras.engine.sequential.Sequential at 0x231a468d640>,
#  <keras.engine.sequential.Sequential at 0x231a4345760>,
#  <keras.engine.sequential.Sequential at 0x231a48e1190>,
#  <keras.engine.sequential.Sequential at 0x231a48f3220>,
#  <keras.engine.sequential.Sequential at 0x231a48cb700>,
#  <keras.engine.sequential.Sequential at 0x231a43156a0>,
#  <keras.engine.sequential.Sequential at 0x231a45fffa0>,
#  <keras.engine.sequential.Sequential at 0x231a48e1910>,
#  <keras.engine.sequential.Sequential at 0x2319c567b80>,
#  <keras.engine.sequential.Sequential at 0x231a43bc100>,
#  <keras.engine.sequential.Sequential at 0x231a4908820>,
#  <keras.engine.sequential.Sequential at 0x231a3f59b80>,
#  <keras.engine.sequential.Sequential at 0x231a470fdf0>,
#  <keras.engine.sequential.Sequential at 0x2319c54a700>,
#  <keras.engine.sequential.Sequential at 0x231a26d6fd0>,
#  <keras.engine.sequential.Sequential at 0x231a470fa90>,
#  <keras.engine.sequential.Sequential at 0x231a8f4b160>,
#  <keras.engine.sequential.Sequential at 0x2319c436160>,
#  <keras.engine.sequential.Sequential at 0x2319c557ca0>,
#  <keras.engine.sequential.Sequential at 0x231a4949400>,
#  <keras.engine.sequential.Sequential at 0x231a4949670>,
#  <keras.engine.sequential.Sequential at 0x231a48e12b0>,
#  <keras.engine.sequential.Sequential at 0x231a44db8e0>,
#  <keras.engine.sequential.Sequential at 0x2319c54a4f0>,
#  <keras.engine.sequential.Sequential at 0x231a46e46a0>,
#  <keras.engine.sequential.Sequential at 0x2319c34deb0>,
#  <keras.engine.sequential.Sequential at 0x231a42723a0>,
#  <keras.engine.sequential.Sequential at 0x231a49822b0>,
#  <keras.engine.sequential.Sequential at 0x231a26d6c40>,
#  <keras.engine.sequential.Sequential at 0x231a496fcd0>,
#  <keras.engine.sequential.Sequential at 0x231a48f3ee0>,
#  <keras.engine.sequential.Sequential at 0x231a4216550>,
#  <keras.engine.sequential.Sequential at 0x231a458e250>,
#  <keras.engine.sequential.Sequential at 0x231a49a3ac0>,
#  <keras.engine.sequential.Sequential at 0x231a4368190>,
#  <keras.engine.sequential.Sequential at 0x231a4929d60>,
#  <keras.engine.sequential.Sequential at 0x231a47c2c10>,
#  <keras.engine.sequential.Sequential at 0x231a4647b80>,
#  <keras.engine.sequential.Sequential at 0x231a9072070>,
#  <keras.engine.sequential.Sequential at 0x231a43684c0>,
#  <keras.engine.sequential.Sequential at 0x231a27bf460>,
#  <keras.engine.sequential.Sequential at 0x2319c7571c0>,
#  <keras.engine.sequential.Sequential at 0x231a4385460>,
#  <keras.engine.sequential.Sequential at 0x231a7ef0730>,
#  <keras.engine.sequential.Sequential at 0x231a4793460>]

# %%
import os
# import configparser
# def get_inputs_from_config(path = '\\configs\\', config_name = 'neural_network.cfg'):
#     current_path = os.getcwd()
#     print(current_path)
#     config_path = current_path + path + config_name
    
#     configParser = configparser.RawConfigParser()   
#     configFilePath = config_path
#     configParser.readfp(open(config_path))
#     inputs = [i[1].split(",") if "," in i[1] else i[1] for i in list(configParser.items('Neural_Network_Generator'))]
#     return inputs
